# %% [markdown]
# ## Pandas and plotting

# %%
import pandas as pd

# %%
data = pd.read_csv('data/gapminder_gdp_oceania.csv')
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %% [markdown]
# <img src="http://r4ds.had.co.nz/images/tidy-1.png">

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
# country           2 non-null object
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 288.0+ bytes

# %%
data.columns
# Out:
# Index(['country', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')

# %%
data.T
# Out:
#                         0            1
# country         Australia  New Zealand
# gdpPercap_1952    10039.6      10556.6
# gdpPercap_1957    10949.6      12247.4
# gdpPercap_1962    12217.2      13175.7
# gdpPercap_1967    14526.1      14463.9
# gdpPercap_1972    16788.6        16046
# gdpPercap_1977    18334.2      16233.7
# gdpPercap_1982      19477      17632.4
# gdpPercap_1987    21888.9      19007.2
# gdpPercap_1992    23424.8      18363.3
# gdpPercap_1997    26997.9      21050.4
# gdpPercap_2002    30687.8      23189.8
# gdpPercap_2007    34435.4        25185

# %%
data.dtypes
# Out:
# country            object
# gdpPercap_1952    float64
# gdpPercap_1957    float64
# gdpPercap_1962    float64
# gdpPercap_1967    float64
# gdpPercap_1972    float64
# gdpPercap_1977    float64
# gdpPercap_1982    float64
# gdpPercap_1987    float64
# gdpPercap_1992    float64
# gdpPercap_1997    float64
# gdpPercap_2002    float64
# gdpPercap_2007    float64
# dtype: object

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
americas = pd.read_csv('data/gapminder_gdp_americas.csv')
americas.head(3)
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina     5911.315053     6856.856212     7133.166023
# 1  Americas    Bolivia     2677.326347     2127.686326     2180.972546
# 2  Americas     Brazil     2108.944355     2487.365989     3336.585802
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     8052.953021     9443.038526    10079.026740     8997.897412
# 1     2586.886053     2980.331339     3548.097832     3156.510452
# 2     3429.864357     4985.711467     6660.118654     7030.835878
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     9139.671389     9308.418710    10967.281950     8797.640716
# 1     2753.691490     2961.699694     3326.143191     3413.262690
# 2     7807.095818     6950.283021     7957.980824     8131.212843
#
#    gdpPercap_2007
# 0    12779.379640
# 1     3822.137084
# 2     9065.800825

# %%
data = pd.read_csv('data/gapminder_gdp_europe.csv',index_col='country')
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
data.iloc[:2,:2]
# Out:
#          gdpPercap_1952  gdpPercap_1957
# country
# Albania     1601.056136     1942.284244
# Austria     6137.076492     8842.598030

# %%
data.loc['Albania',:]
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
data.loc[:,'gdpPercap_1962']
# Out:
# country
# Albania                    2312.888958
# Austria                   10750.721110
# Belgium                   10991.206760
# Bosnia and Herzegovina     1709.683679
# Bulgaria                   4254.337839
# Croatia                    5477.890018
# Czech Republic            10136.867130
# Denmark                   13583.313510
# Finland                    9371.842561
# France                    10560.485530
# Germany                   12902.462910
# Greece                     6017.190733
# Hungary                    7550.359877
# Iceland                   10350.159060
# Ireland                    6631.597314
# Italy                      8243.582340
# Montenegro                 4649.593785
# Netherlands               12790.849560
# Norway                    13450.401510
# Poland                     5338.752143
# Portugal                   4727.954889
# Romania                    4734.997586
# Serbia                     6289.629157
# Slovak Republic            7481.107598
# ...

# %%
data.gdpPercap_1952

# %%
data['gdpPercap_1952']
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
pd.DataFrame(data.loc['Albania',:])
# Out:
#                     Albania
# gdpPercap_1952  1601.056136
# gdpPercap_1957  1942.284244
# gdpPercap_1962  2312.888958
# gdpPercap_1967  2760.196931
# gdpPercap_1972  3313.422188
# gdpPercap_1977  3533.003910
# gdpPercap_1982  3630.880722
# gdpPercap_1987  3738.932735
# gdpPercap_1992  2497.437901
# gdpPercap_1997  3193.054604
# gdpPercap_2002  4604.211737
# gdpPercap_2007  5937.029526

# %%
data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'].describe()
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        5.000000        5.000000        5.000000
# mean      8894.635868    10842.506571    13162.799194
# std       4093.410673     4855.106424     5517.298708
# min       4649.593785     5907.850937     7778.414017
# 25%       5338.752143     6557.152776     8006.506993
# 50%       8243.582340    10022.401310    12269.273780
# 75%      12790.849560    15363.251360    18794.745670
# max      13450.401510    16361.876470    18965.055510

# %%
(data.
 loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'].
 describe())
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        5.000000        5.000000        5.000000
# mean      8894.635868    10842.506571    13162.799194
# std       4093.410673     4855.106424     5517.298708
# min       4649.593785     5907.850937     7778.414017
# 25%       5338.752143     6557.152776     8006.506993
# 50%       8243.582340    10022.401310    12269.273780
# 75%      12790.849560    15363.251360    18794.745670
# max      13450.401510    16361.876470    18965.055510

# %%
subset  = data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']

# %%
subset > 10000
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
mask = subset >10000
subset[mask]
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                   NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN
# Netherlands     12790.84956     15363.25136     18794.74567
# Norway          13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN

# %%
subset[mask].describe()
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320
# std        466.373656     3408.589070     3817.597015
# min      12790.849560    10022.401310    12269.273780
# 25%      12955.737547    12692.826335    15532.009725
# 50%      13120.625535    15363.251360    18794.745670
# 75%      13285.513523    15862.563915    18879.900590
# max      13450.401510    16361.876470    18965.055510

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x, y)

# %%
df_oceania = pd.read_csv('data/gapminder_gdp_oceania.csv',index_col= 'country')
df_oceania.loc['Australia'].plot()

# %%
df_oceania.T.plot()

# %%
plt.style.use('ggplot')
df_oceania.T.plot(kind = 'bar')

# %%
data = pd.read_csv('data/gapminder_gdp_oceania.csv')
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
df_melted = (data.
 melt(id_vars= 'country',
      value_name='gdp_per_capita',
      var_name= 'year')) 

df_melted
# Out:
#         country            year  gdp_per_capita
# 0     Australia  gdpPercap_1952     10039.59564
# 1   New Zealand  gdpPercap_1952     10556.57566
# 2     Australia  gdpPercap_1957     10949.64959
# 3   New Zealand  gdpPercap_1957     12247.39532
# 4     Australia  gdpPercap_1962     12217.22686
# 5   New Zealand  gdpPercap_1962     13175.67800
# 6     Australia  gdpPercap_1967     14526.12465
# 7   New Zealand  gdpPercap_1967     14463.91893
# 8     Australia  gdpPercap_1972     16788.62948
# 9   New Zealand  gdpPercap_1972     16046.03728
# 10    Australia  gdpPercap_1977     18334.19751
# 11  New Zealand  gdpPercap_1977     16233.71770
# 12    Australia  gdpPercap_1982     19477.00928
# 13  New Zealand  gdpPercap_1982     17632.41040
# 14    Australia  gdpPercap_1987     21888.88903
# 15  New Zealand  gdpPercap_1987     19007.19129
# 16    Australia  gdpPercap_1992     23424.76683
# 17  New Zealand  gdpPercap_1992     18363.32494
# 18    Australia  gdpPercap_1997     26997.93657
# ...

# %%
df_melted['year'] = df_melted.year.str.replace('gdpPercap_','')

# %%
df_melted
# Out:
#         country  year  gdp_per_capita
# 0     Australia  1952     10039.59564
# 1   New Zealand  1952     10556.57566
# 2     Australia  1957     10949.64959
# 3   New Zealand  1957     12247.39532
# 4     Australia  1962     12217.22686
# 5   New Zealand  1962     13175.67800
# 6     Australia  1967     14526.12465
# 7   New Zealand  1967     14463.91893
# 8     Australia  1972     16788.62948
# 9   New Zealand  1972     16046.03728
# 10    Australia  1977     18334.19751
# 11  New Zealand  1977     16233.71770
# 12    Australia  1982     19477.00928
# 13  New Zealand  1982     17632.41040
# 14    Australia  1987     21888.88903
# 15  New Zealand  1987     19007.19129
# 16    Australia  1992     23424.76683
# 17  New Zealand  1992     18363.32494
# 18    Australia  1997     26997.93657
# 19  New Zealand  1997     21050.41377
# 20    Australia  2002     30687.75473
# 21  New Zealand  2002     23189.80135
# 22    Australia  2007     34435.36744
# 23  New Zealand  2007     25185.00911

# %%
import seaborn as sns

# %%
sns.pointplot(x = 'year', y= 'gdp_per_capita', hue = 'country',data= df_melted)

# %%
sns.pointplot(x = 'year', y= 'gdp_per_capita', data= df_melted)
